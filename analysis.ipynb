# %%
import pandas as pd

# %%
df = pd.read_csv('jobs.csv')
df.head()
# Out:
#               id      site                                        job_url  \
# 0  li-4298884601  linkedin  https://www.linkedin.com/jobs/view/4298884601
# 1  li-4402247252  linkedin  https://www.linkedin.com/jobs/view/4402247252
# 2  li-4402299100  linkedin  https://www.linkedin.com/jobs/view/4402299100
# 3  li-4398472597  linkedin  https://www.linkedin.com/jobs/view/4398472597
# 4  li-4401742094  linkedin  https://www.linkedin.com/jobs/view/4401742094
#
#    job_url_direct                    title                       company  \
# 0             NaN              Associate 2                PwC Uzbekistan
# 1             NaN       Investment Officer  Asian Development Bank (ADB)
# 2             NaN  Site Operations Manager                      DataVolt
# 3             NaN    Junior System Analyst                  Andersen Lab
# 4             NaN            Sales Manager                 M I R A L.L.C
#
#                                location date_posted  job_type  salary_source  \
# ...
